# %% [markdown]
# ## Collaborative Filtering:
# $$ Utility Matrix \mapsto Normalized \mapsto Similarity~matrix \mapsto Predict $$

# %%
from IPython.display import Image

Image('user_cf.png')
#----------------------------------#
#RESOURCE: machinelearningcoban.com
#----------------------------------#

# %%
from numpy import *

class CF(object):
    def __init__(self, data):
        self.data = data
        self.n_user = len(set(self.data.iloc[:, 0]))
        self.n_item = int(max(self.data.iloc[:, 1]))
    
#    def normalized(self):

# %%
import pandas as pd

# %%
r_cols = ['user_id', 'item_id', 'rating']
data = pd.read_csv('https://raw.githubusercontent.com/tiepvupsu/tiepvupsu.github.io/master/assets/24_collaborativefiltering/python/ex.dat',
                  sep= ' ',
                  names = r_cols)

# %%
trial = CF(data)
trial.n_user()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-2b3b2b270c54> in <module>()
#       1 trial = CF(data)
# ----> 2 trial.n_user()
#
# TypeError: 'int' object is not callable

# %%
trial.n_item
# Out:
# 4

# %%
len(set(data.iloc[:,0]))
# Out:
# 7

# %%
data
# Out:
#     user_id  item_id  rating
# 0         0        0     5.0
# 1         0        1     4.0
# 2         0        3     2.0
# 3         0        4     2.0
# 4         1        0     5.0
# 5         1        2     4.0
# 6         1        3     2.0
# 7         1        4     0.0
# 8         2        0     2.0
# 9         2        2     1.0
# 10        2        3     3.0
# 11        2        4     4.0
# 12        3        0     0.0
# 13        3        1     0.0
# 14        3        3     4.0
# 15        4        0     1.0
# 16        4        3     4.0
# 17        5        1     2.0
# 18        5        2     1.0
# 19        6        2     1.0
# 20        6        3     4.0
# 21        6        4     5.0
