# %%
#Getting data
#---------------------------------------#
import pandas as pd

data = pd.read_csv('weatherHistory.csv')
data.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# ...

# %%
data.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                     251          15.8263           0               1015.13
# ...

# %%
data.dtypes
# Out:
# Formatted Date               object
# Summary                      object
# Precip Type                  object
# Temperature (C)             float64
# Apparent Temperature (C)    float64
# Humidity                    float64
# Wind Speed (km/h)           float64
# Wind Bearing (degrees)        int64
# Visibility (km)             float64
# Loud Cover                    int64
# Pressure (millibars)        float64
# Daily Summary                object
# dtype: object

# %%
#Preparing data
#---------------------------------------#

y = data['Apparent Temperature (C)']

columns_name = []
for column in data.columns:
    dt = data[column].dtypes
    if dt == 'float64' or dt == 'int64':
        columns_name.append(column)
        
X = data[columns_name]
X = X.loc[:, X.columns != 'Apparent Temperature (C)']

# %%
#Data preprocessing
#---------------------------------------#

from sklearn.preprocessing import StandardScaler

std = StandardScaler()
X = std.fit_transform(X)

# %%
#Splitting data
#---------------------------------------#

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
#Predict
#---------------------------------------#

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

lrg = LinearRegression()
lrg.fit(X_train, y_train)
y_predict = lrg.predict(X_test)

mean_squared_error(y_predict, y_test)
# Out:
# 1.1622528579437403

# %%
from sklearn import datasets, neighbors, linear_model

digits = datasets.load_digits()
X_digits = digits.data
y_digits = digits.target

n_samples = len(X_digits)

X_train = X_digits[:int(.9 * n_samples)]
y_train = y_digits[:int(.9 * n_samples)]
X_test = X_digits[int(.9 * n_samples):]
y_test = y_digits[int(.9 * n_samples):]

knn = neighbors.KNeighborsClassifier()
logistic = linear_model.LogisticRegression()

print('KNN score: %f' % knn.fit(X_train, y_train).score(X_test, y_test))
print('LogisticRegression score: %f'
      % logistic.fit(X_train, y_train).score(X_test, y_test))
# Out:
# KNN score: 0.961111
# LogisticRegression score: 0.938889

# %%
from sklearn.decomposition import PCA

# %%
print('KNN score: %f' % knn.fit(X_train_pca, y_train).score(X_test_pca, y_test))
print('LogisticRegression score: %f'
      % logistic.fit(X_train_pca, y_train).score(X_test_pca, y_test))
# Out:
# KNN score: 0.961111
# LogisticRegression score: 0.933333

# %%
for i in range(10,30):
    pca = PCA(n_components=i)
    X_pca = pca.fit_transform(X_digits)
    X_train_pca = X_pca[:int(.9 * n_samples)]
    X_test_pca = X_pca[int(.9 * n_samples):]
    print(i)
    print('KNN score: %f' % knn.fit(X_train_pca, y_train).score(X_test_pca, y_test))
    print('LogisticRegression score: %f'
      % logistic.fit(X_train_pca, y_train).score(X_test_pca, y_test))
    print('_'*20)
# Out:
# 10
# KNN score: 0.933333
# LogisticRegression score: 0.872222
# ____________________
# 11
# KNN score: 0.938889
# LogisticRegression score: 0.883333
# ____________________
# 12
# KNN score: 0.944444
# LogisticRegression score: 0.883333
# ____________________
# 13
# KNN score: 0.955556
# LogisticRegression score: 0.888889
# ____________________
# 14
# KNN score: 0.961111
# LogisticRegression score: 0.900000
# ____________________
# 15
# KNN score: 0.961111
# LogisticRegression score: 0.911111
# ____________________
# 16
# KNN score: 0.966667
# LogisticRegression score: 0.911111
# ____________________
# 17
# KNN score: 0.961111
# LogisticRegression score: 0.916667
# ____________________
# 18
# KNN score: 0.961111
# LogisticRegression score: 0.916667
# ____________________
# 19
# KNN score: 0.955556
# LogisticRegression score: 0.911111
# ____________________
# 20
# KNN score: 0.955556
# LogisticRegression score: 0.938889
# ____________________
# 21
# KNN score: 0.961111
# ...

# %%
#hessian eigenmap, Laplacian eigenmap, sparse PCA
