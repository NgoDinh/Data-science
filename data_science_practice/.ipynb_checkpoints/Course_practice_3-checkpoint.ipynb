# %%
import nltk
import pandas as pd

# %%
data = pd.read_csv('data-trim.csv')
X = data['content']
y = data['type']
#X = [art for art in X if type(art) != float]

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/mmr/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=1)

# %%
len(X)
# Out:
# 1000

# %%
token_collection = []
for i in range(800):
    token = nltk.word_tokenize(X_train[1])
    token_collection = list(set(token_collection))
    token_collection.extend(list(set(token)))

# %%
token_collection = [word for word in token_collection if len(word) > 1]
token_collection = [word.upper() for word in token_collection]
token_collection
# Out:
# ['LUẬT',
#  'HĐND',
#  'BẮC',
#  'ÍCH',
#  'ĐIỀU',
#  'TÂY',
#  'CHỈ',
#  'TỊCH',
#  'TRƯƠNG',
#  'VỤ',
#  'KHÁM',
#  'PHẠM',
#  'CHÊNH',
#  'VIỆC',
#  'PHỤC',
#  'VƯỚNG',
#  'UBND',
#  'VỀ',
#  'TRƯỞNG',
#  'TIẾNG',
#  'ĐÃ',
#  'GIẢI',
#  'TƯ',
#  'NÀY',
#  'HƯỚNG',
#  'SÓC',
#  'CUỘC',
#  'TẾ',
#  'XUẤT',
#  'ĐẨY',
#  'CẤP',
#  'THIẾU',
#  'KHÓA',
#  'THÊM',
#  '2009',
#  'NHƯ',
#  'TIỀN',
#  'TỤC',
#  'NHÀ',
#  'ĐẠI',
#  'ĐỀN',
#  'NHU',
#  'TRƯỜNG',
#  'TỪ',
#  'BỆNH',
#  'KIÊM',
#  'NAY',
#  'NẢY',
#  'MÀ',
#  'NHA',
#  'CỬ',
#  'VĂN',
#  'CHO',
#  'CHỮA',
#  '20',
#  'SẼ',
#  'KINH',
#  'CHĂM',
#  'BIỆT',
#  'TÁC',
#  'VĨNH',
#  'HUẾ',
#  'SỐNG',
#  'THÚC',
#  'ĐỨC',
#  'KIẾN',
#  'THẮC',
#  'CAM',
#  'HỨA',
#  'GIÁM',
#  'PHÁP',
#  'NHƯNG',
#  'MONG',
#  'GHI',
#  'VIÊN',
#  'TRONG',
#  'HUYỆN',
#  'SỨC',
#  'THIỆT',
#  'NHÂN',
#  'HƠN',
#  'LIÊN',
#  'LỐI',
#  'KIỀU',
#  'DỰ',
#  'MỤC',
#  'GIA',
#  'TỎA',
#  'SỸ',
#  'NHẰM',
#  'THẾ',
#  'ĐỊA',
#  'LỢI',
#  'ỨNG',
# ...

# %%
X_train_tf = []
for sentence in X_train:
    temp = []
    for word in token_collection:
        try:
            temp.append(sentence.upper().count(word) / len(sentence))
        except:
            temp.append(0)
    X_train_ma.append(temp)

# %%
from sklearn.feature_extraction.text import CountVectorizer
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)
from sklearn.feature_extraction.text import TfidfTransformer
tf_transformer = TfidfTransformer(use_idf=False).fit(X_train_counts)
X_train_tf = tf_transformer.transform(X_train_counts)
X_train_tf.shape
