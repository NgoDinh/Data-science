# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/NgoDinh/Data-science/blob/master/Deep_learning/keras_Visualizing_what_conv_learn.ipynb)

# %%
from keras.models import load_model

model = load_model('cats_and_dogs_small_1.h5')
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 15, 15, 128)       147584
# ...

# %%
img_path = 'C:\\Users\\admin\\Downloads\\result\\test\\cats\\cat.1700.jpg'
from keras.preprocessing import image
import numpy as np

img = image.load_img(img_path, target_size=(150, 150))
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)
# Remember that the model was trained on inputs
# that were preprocessed in the following way:
img_tensor /= 255.

# Its shape is (1, 150, 150, 3)
print(img_tensor.shape)
# Out:
# (1, 150, 150, 3)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.imshow(img_tensor[0])
plt.show()

# %%
from keras import models

# %%
layer_outputs = [layer.output for layer in model.layers[:8]]
activation_model = models.Model(inputs = model.input, outputs = layer_outputs)

# %%
activations = activation_model.predict(img_tensor)

# %%
first_layer_activation = activations[0]
# %matplotlib inline
import matplotlib.pyplot as plt

plt.matshow(first_layer_activation[0, :, :, 4], cmap='viridis')
plt.show()

# %%
second_layer_activation = activations[1]
# %matplotlib inline
import matplotlib.pyplot as plt

plt.matshow(second_layer_activation[0, :, :, 4], cmap='viridis')
plt.show()

# %%
third_layer_activation = activations[2]
# %matplotlib inline
import matplotlib.pyplot as plt

plt.matshow(third_layer_activation[0, :, :, 4], cmap='viridis')
plt.show()

# %%
fourth_layer_activation = activations[3]
# %matplotlib inline
import matplotlib.pyplot as plt

plt.matshow(fourth_layer_activation[0, :, :, 4], cmap='viridis')
plt.show()

# %%
fifth_layer_activation = activations[4]
# %matplotlib inline
import matplotlib.pyplot as plt

plt.matshow(fifth_layer_activation[0, :, :, 4], cmap='viridis')
plt.show()

# %%
sixth_layer_activation = activations[5]
# %matplotlib inline
import matplotlib.pyplot as plt

plt.matshow(sixth_layer_activation[0, :, :, 4], cmap='viridis')
plt.show()

# %%
seventh_layer_activation = activations[6]
# %matplotlib inline
import matplotlib.pyplot as plt

plt.matshow(seventh_layer_activation[0, :, :, 4], cmap='viridis')
plt.show()
